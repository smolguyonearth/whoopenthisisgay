# %%
import numpy as np
import pandas as pd

# %%
df_bkk = pd.read_csv("../../data3/bangkok_weather.csv")
df_cnx = pd.read_csv("../../data3/chiangmai_weather.csv")
df_kkc = pd.read_csv("../../data3/khonkaen_weather.csv")
df_hkt = pd.read_csv("../../data3/phuket_weather.csv")
df_chb = pd.read_csv("../../data3/chonburi_weather.csv")
df_kcb = pd.read_csv("../../data3/kanchanaburi_weather.csv")

# %%
df_bkk
# Out:
#             date  temperature_max  temperature_avg  temperature_min  \
# 0     2025-04-01             95.0             86.3             79.0
# 1     2025-04-02             95.0             87.4             82.0
# 2     2025-04-03             95.0             87.0             82.0
# 3     2025-04-04             93.0             86.4             82.0
# 4     2025-04-05             95.0             87.2             82.0
# ...          ...              ...              ...              ...
# 9762  1997-01-27             84.0             77.0             73.0
# 9763  1997-01-28             91.0             81.7             72.0
# 9764  1997-01-29             95.0             84.2             73.0
# 9765  1997-01-30             95.0             83.0             73.0
# 9766  1997-01-31             93.0             81.3             75.0
#
#       dew_point_max  dew_point_avg  dew_point_min  humidity_max  humidity_avg  \
# ...

# %%
print(df_bkk.info())
print("-"*20)
print(df_cnx.info())
print("-"*20)
print(df_kkc.info())
print("-"*20)
print(df_hkt.info())
print("-"*20)
print(df_chb.info())
print("-"*20)
print(df_kcb.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9767 entries, 0 to 9766
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             9767 non-null   object
#  1   temperature_max  9767 non-null   float64
#  2   temperature_avg  9767 non-null   float64
#  3   temperature_min  9767 non-null   float64
#  4   dew_point_max    9767 non-null   float64
#  5   dew_point_avg    9767 non-null   float64
#  6   dew_point_min    9767 non-null   float64
#  7   humidity_max     9767 non-null   float64
#  8   humidity_avg     9767 non-null   float64
#  9   humidity_min     9767 non-null   float64
#  10  wind_speed_max   9767 non-null   float64
#  11  wind_speed_avg   9767 non-null   float64
#  12  wind_speed_min   9767 non-null   float64
#  13  pressure_max     9767 non-null   float64
#  14  pressure_avg     9767 non-null   float64
#  15  pressure_min     9767 non-null   float64
# ...

# %%
df_chb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4018 entries, 0 to 4017
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             4018 non-null   object
#  1   temperature_max  4017 non-null   float64
#  2   temperature_avg  4017 non-null   float64
#  3   temperature_min  4017 non-null   float64
#  4   dew_point_max    4017 non-null   float64
#  5   dew_point_avg    4017 non-null   float64
#  6   dew_point_min    4017 non-null   float64
#  7   humidity_max     4017 non-null   float64
#  8   humidity_avg     4017 non-null   float64
#  9   humidity_min     4017 non-null   float64
#  10  wind_speed_max   4017 non-null   float64
#  11  wind_speed_avg   4017 non-null   float64
#  12  wind_speed_min   4017 non-null   float64
#  13  pressure_max     4017 non-null   float64
#  14  pressure_avg     4017 non-null   float64
#  15  pressure_min     4017 non-null   float64
# ...

# %%
df_chb.head(10)
# Out:
#         date  temperature_max  temperature_avg  temperature_min  \
# 0   1/1/2014             84.0        74.416667             64.0
# 1   2/1/2014             88.0        75.395833             66.0
# 2   3/1/2014             91.0        78.333333             66.0
# 3   4/1/2014             91.0        78.687500             68.0
# 4   5/1/2014             90.0        79.333333             72.0
# 5   6/1/2014             91.0        80.229167             72.0
# 6   7/1/2014             91.0        80.770833             72.0
# 7   8/1/2014             91.0        82.083333             75.0
# 8   9/1/2014             91.0        83.458333             75.0
# 9  10/1/2014             88.0        80.608696             73.0
#
#    dew_point_max  dew_point_avg  dew_point_min  humidity_max  humidity_avg  \
# 0           63.0      57.875000           55.0          78.0     57.645833
# 1           63.0      58.229167           54.0          78.0     57.500000
# ...

# %%
df_chb.tail(10)
# Out:
#             date  temperature_max  temperature_avg  temperature_min  \
# 4008  22/12/2024             82.0        76.645833             70.0
# 4009  23/12/2024             84.0        76.312500             68.0
# 4010  24/12/2024             86.0        78.791667             72.0
# 4011  25/12/2024             88.0        80.083333             73.0
# 4012  26/12/2024             86.0        81.041667             75.0
# 4013  27/12/2024             91.0        84.145833             77.0
# 4014  28/12/2024             88.0        83.145833             79.0
# 4015  29/12/2024             86.0        80.458333             73.0
# 4016  30/12/2024             90.0        81.333333             73.0
# 4017  31/12/2024             88.0        80.354167             72.0
#
#       dew_point_max  dew_point_avg  dew_point_min  humidity_max  humidity_avg  \
# 4008           64.0      59.020833           57.0          73.0     55.166667
# ...

# %%
#where is the missing data?
df_chb[df_chb['temperature_max'].isnull()]
# Out:
#         date  temperature_max  temperature_avg  temperature_min  \
# 31  1/2/2014              NaN              NaN              NaN
#
#     dew_point_max  dew_point_avg  dew_point_min  humidity_max  humidity_avg  \
# 31            NaN            NaN            NaN           NaN           NaN
#
#     humidity_min  wind_speed_max  wind_speed_avg  wind_speed_min  \
# 31           NaN             NaN             NaN             NaN
#
#     pressure_max  pressure_avg  pressure_min  precipitation
# 31           NaN           NaN           NaN            NaN

# %%
from sklearn.impute import KNNImputer
import pandas as pd

# Only select numeric columns
df_numeric = df_chb.select_dtypes(include=['number'])

# Drop the 'precipitation' column as it contains only NaN values
df_numeric_without_precipitation = df_numeric.drop(columns=['precipitation'])

# Impute only numeric part
imputer = KNNImputer(n_neighbors=5)
df_numeric_imputed = pd.DataFrame(imputer.fit_transform(df_numeric_without_precipitation), columns=df_numeric_without_precipitation.columns)

# Add the 'precipitation' column back with NaN values
df_numeric_imputed['precipitation'] = df_numeric['precipitation'].values

# Now if you want to combine back with the original non-numeric columns:
df_non_numeric = df_chb.select_dtypes(exclude=['number']).reset_index(drop=True)
df_imputed = pd.concat([df_numeric_imputed, df_non_numeric], axis=1)

# Example access
print(df_imputed.loc[31])
# Out:
# temperature_max    91.296988
# temperature_avg    84.252377
# temperature_min    78.202888
# dew_point_max      75.200149
# dew_point_avg      71.977155
# dew_point_min      68.431168
# humidity_max       84.810804
# humidity_avg       68.124576
# humidity_min       49.547672
# wind_speed_max     14.312422
# wind_speed_avg       7.54398
# wind_speed_min       2.03535
# pressure_max       29.871187
# pressure_avg       29.801338
# pressure_min       29.726888
# precipitation            NaN
# date                1/2/2014
# Name: 31, dtype: object

# %%
df_imputed['date'] = pd.to_datetime(df_imputed['date'], dayfirst=True)
df_imputed = df_imputed.sort_values('date')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))
plt.plot(df_imputed['date'], df_imputed['temperature_max'], label='Max Temp')
plt.plot(df_imputed['date'], df_imputed['temperature_avg'], label='Avg Temp')
plt.plot(df_imputed['date'], df_imputed['temperature_min'], label='Min Temp')
plt.title('Temperature Trends')
plt.xlabel('Date')
plt.ylabel('Temperature (F)')
plt.legend()
plt.grid(True)
plt.show()

# %%
#try arima
from statsmodels.tsa.arima.model import ARIMA

df_imputed['date'] = pd.to_datetime(df_imputed['date'])
df_imputed.set_index('date', inplace=True)

# %%
series = df_imputed['temperature_avg']

# %%
from statsmodels.tsa.arima.model import ARIMA

# (p, d, q) can be tuned, here (1,1,1) is a basic starting point
model = ARIMA(series, order=(1, 1, 1))
model_fit = model.fit()

# Forecast next 30 days
forecast = model_fit.forecast(steps=30)
print(forecast)
# Out:
# 2025-01-01    80.666761
# 2025-01-02    80.889768
# 2025-01-03    81.048863
# 2025-01-04    81.162363
# 2025-01-05    81.243335
# 2025-01-06    81.301101
# 2025-01-07    81.342312
# 2025-01-08    81.371712
# 2025-01-09    81.392686
# 2025-01-10    81.407649
# 2025-01-11    81.418324
# 2025-01-12    81.425939
# 2025-01-13    81.431372
# 2025-01-14    81.435248
# 2025-01-15    81.438014
# 2025-01-16    81.439986
# 2025-01-17    81.441393
# 2025-01-18    81.442397
# 2025-01-19    81.443114
# 2025-01-20    81.443625
# 2025-01-21    81.443989
# 2025-01-22    81.444249
# 2025-01-23    81.444435
# 2025-01-24    81.444567
# 2025-01-25    81.444662
# 2025-01-26    81.444729
# 2025-01-27    81.444777
# 2025-01-28    81.444811
# 2025-01-29    81.444836
# 2025-01-30    81.444853
# Freq: D, Name: predicted_mean, dtype: float64
# ...

# %%
plt.figure(figsize=(14,7))
plt.plot(series, label='Observed')
plt.plot(pd.date_range(series.index[-1], periods=30, freq='D'), forecast, label='Forecast', color='red')
plt.title('Temperature Forecast with ARIMA')
plt.xlabel('Date')
plt.ylabel('Temperature (F)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# First, make sure 'series' has a proper datetime index
# Assume your 'series' is already set with date as index

# Define the starting point (last 6 months)
start_date = series.index.max() - pd.DateOffset(months=6)

# Slice observed series
series_last6months = series[series.index >= start_date]

# For forecast, you usually want the whole forecast because it's future — keep it.

# Now plot
plt.figure(figsize=(14,7))
plt.plot(series_last6months, label='Observed (Last 6 Months)')
plt.plot(pd.date_range(series.index[-1], periods=30, freq='D'), forecast, label='Forecast', color='red')
plt.title('Temperature Forecast - Last 6 Months')
plt.xlabel('Date')
plt.ylabel('Temperature (F)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Step 2: Select the temperature series you want to predict
series = df_imputed['temperature_avg']

# Step 3: Rolling forecast (dynamic prediction)
history = list(series)
predictions = []

n_forecast_days = 30

for t in range(n_forecast_days):
    model = ARIMA(history, order=(1, 1, 1))  # You can tune (p,d,q) if needed
    model_fit = model.fit()
    yhat = model_fit.forecast()[0]  # Forecast the next day
    predictions.append(yhat)
    history.append(yhat)  # Use predicted value as new input

# Step 4: Build the forecast index (dates)
forecast_dates = pd.date_range(series.index[-1] + pd.Timedelta(days=1), periods=n_forecast_days)

# Step 5: Plotting
# Zoom to last 6 months
start_date = series.index.max() - pd.DateOffset(months=6)
series_last6months = series[series.index >= start_date]

plt.figure(figsize=(14,7))
plt.plot(series_last6months, label='Observed (Last 6 Months)')
plt.plot(forecast_dates, predictions, label='Forecast (Next 30 Days)', color='red', linestyle='--')
plt.title('Temperature Forecast with Rolling ARIMA')
plt.xlabel('Date')
plt.ylabel('Temperature (F)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Step 2: Select the temperature series you want to predict
series = df_imputed['temperature_avg']

# Step 3: Prepare a list to store predictions
predictions = []

# Step 4: Rolling forecast (predict one day at a time)
for t in range(len(series), len(series) + 30):  # Predict the next 30 days
    model = ARIMA(series, order=(1, 1, 1))  # You can tune (p,d,q) if needed
    model_fit = model.fit()
    yhat = model_fit.forecast()[0]  # Forecast the next day
    predictions.append(yhat)
    
    # Append the prediction to the series to use it for the next prediction
    # Use pd.concat instead of .append()
    new_data = pd.Series([yhat], index=[series.index[-1] + pd.Timedelta(days=1)])
    series = pd.concat([series, new_data])

# Step 5: Build the forecast index (dates for the next 30 days)
forecast_dates = pd.date_range(series.index[-30], periods=30, freq='D')

# Step 6: Plotting the forecast
plt.figure(figsize=(14,7))
plt.plot(df_imputed['temperature_avg'], label='Observed')
plt.plot(forecast_dates, predictions, label='Forecast (Next 30 Days)', color='red', linestyle='--')
plt.title('Temperature Forecast with Rolling ARIMA (Using All Data)')
plt.xlabel('Date')
plt.ylabel('Temperature (F)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# ...

# %%
# Step 2: Select the temperature series you want to predict
series = df_imputed['temperature_avg']

# Step 3: Prepare a list to store predictions
predictions = []

# Step 4: Rolling forecast (predict one day at a time)
for t in range(len(series), len(series) + 30):  # Predict the next 30 days
    model = ARIMA(series, order=(1, 1, 1))  # You can tune (p,d,q) if needed
    model_fit = model.fit()
    yhat = model_fit.forecast()[0]  # Forecast the next day
    predictions.append(yhat)
    
    # Append the prediction to the series to use it for the next prediction
    new_data = pd.Series([yhat], index=[series.index[-1] + pd.Timedelta(days=1)])
    series = pd.concat([series, new_data])

# Step 5: Build the forecast index (dates for the next 30 days)
forecast_dates = pd.date_range(series.index[-30], periods=30, freq='D')

# Step 6: Filter the last 6 months (approx. 180 days) of data
last_6_months = series.last('180D')  # Get the last 6 months of data

# Step 7: Plotting the observed and forecasted values for the last 6 months
plt.figure(figsize=(14, 7))
plt.plot(last_6_months, label='Observed')
plt.plot(forecast_dates, predictions, label='Forecast (Next 30 Days)', color='red', linestyle='--')
plt.title('Temperature Forecast for the Last 6 Months with Rolling ARIMA')
plt.xlabel('Date')
plt.ylabel('Temperature (F)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
import numpy as np

# Step 2: Select the temperature series you want to predict
series = df_imputed['temperature_avg']

# Step 3: Train ARIMA model
model = ARIMA(series, order=(1, 1, 1))  # (p, d, q) can be adjusted
model_fit = model.fit()

# Step 4: Forecast the next 30 days
forecast_steps = 30
forecast = model_fit.forecast(steps=forecast_steps)

# Step 5: Generate forecast dates
forecast_dates = pd.date_range(series.index[-1] + pd.Timedelta(days=1), periods=forecast_steps, freq='D')

# Step 6: Assume you have actual observed data for the next 30 days (if available)
# For demonstration, let's assume you have actual data in 'actual_data' list
# Replace this with your actual observed data if available
actual = df_imputed['temperature_avg'][-30:]  # Example placeholder (use actual values if available)

# Step 7: Compute accuracy metrics
# 1. Mean Absolute Error (MAE)
mae = mean_absolute_error(actual, forecast)

# 2. Mean Squared Error (MSE)
mse = mean_squared_error(actual, forecast)

# 3. Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# 4. Mean Absolute Percentage Error (MAPE)
mape = mean_absolute_percentage_error(actual, forecast)

# 5. R-squared (R²)
ss_residual = np.sum((actual - forecast) ** 2)
ss_total = np.sum((actual - np.mean(actual)) ** 2)
r2 = 1 - (ss_residual / ss_total)

# Print results
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}")
print(f"R-squared (R²): {r2:.2f}")

# Step 8: Plotting the observed and forecasted values
plt.figure(figsize=(14, 7))
plt.plot(series, label='Observed', color='blue')
plt.plot(forecast_dates, forecast, label='Forecast (Next 30 Days)', color='red', linestyle='--')
plt.title('Temperature Forecast with ARIMA')
plt.xlabel('Date')
plt.ylabel('Temperature (F)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# Mean Absolute Error (MAE): 2.47
# Mean Squared Error (MSE): 8.38
# Root Mean Squared Error (RMSE): 2.90
# Mean Absolute Percentage Error (MAPE): 0.03
# R-squared (R²): 1.00

# %%
import itertools
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# Define a function to evaluate ARIMA models with different parameter combinations
def evaluate_arima_models(series, p_values, d_values, q_values):
    best_score, best_cfg = float('inf'), None
    best_model = None
    for p, d, q in itertools.product(p_values, d_values, q_values):
        try:
            model = ARIMA(series, order=(p, d, q))
            model_fit = model.fit()
            predictions = model_fit.forecast(steps=30)  # predict next 30 days
            error = mean_squared_error(series[-30:], predictions)  # Use MSE to evaluate performance
            if error < best_score:
                best_score, best_cfg = error, (p, d, q)
                best_model = model_fit
        except Exception as e:
            continue
    return best_score, best_cfg, best_model

# Define parameter grid for tuning
p_values = range(0, 5)  # AR terms (p)
d_values = range(0, 2)  # Differencing terms (d)
q_values = range(0, 5)  # MA terms (q)

# Evaluate the ARIMA models
best_score, best_cfg, best_model = evaluate_arima_models(series, p_values, d_values, q_values)
print(f"Best ARIMA Model: ARIMA{best_cfg} with MSE={best_score}")

# Use the best model to forecast
forecast = best_model.forecast(steps=30)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# ...

# %%
# Print the AIC and BIC for the selected model
print(f"AIC: {best_model.aic}")
print(f"BIC: {best_model.bic}")
# Out:
# AIC: 15265.553290640215
# BIC: 15284.448162543293

# %%
# Forecast the next 30 days using the best model
forecast = best_model.forecast(steps=30)

# Print the forecasted values
print("\nForecast for the next 30 days:")
print(forecast)

# Plot the results
plt.figure(figsize=(14,7))
plt.plot(series, label='Observed')
plt.plot(pd.date_range(series.index[-1], periods=30, freq='D'), forecast, label='Forecast (Next 30 Days)', color='red', linestyle='--')
plt.title('Temperature Forecast with Tuning ARIMA')
plt.xlabel('Date')
plt.ylabel('Temperature (F)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Forecast for the next 30 days:
# 2025-01-01    80.666761
# 2025-01-02    80.889768
# 2025-01-03    81.048863
# 2025-01-04    81.162363
# 2025-01-05    81.243335
# 2025-01-06    81.301101
# 2025-01-07    81.342312
# 2025-01-08    81.371712
# 2025-01-09    81.392686
# 2025-01-10    81.407649
# 2025-01-11    81.418324
# 2025-01-12    81.425939
# 2025-01-13    81.431372
# 2025-01-14    81.435248
# 2025-01-15    81.438014
# 2025-01-16    81.439986
# 2025-01-17    81.441393
# 2025-01-18    81.442397
# 2025-01-19    81.443114
# 2025-01-20    81.443625
# 2025-01-21    81.443989
# 2025-01-22    81.444249
# 2025-01-23    81.444435
# 2025-01-24    81.444567
# 2025-01-25    81.444662
# 2025-01-26    81.444729
# 2025-01-27    81.444777
# 2025-01-28    81.444811
# 2025-01-29    81.444836
# 2025-01-30    81.444853
# Freq: D, Name: predicted_mean, dtype: float64
