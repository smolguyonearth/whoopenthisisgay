# %%
import numpy as np
import pandas as pd

# %%
df_check = pd.read_excel("../../data/boundaries/tha_adminboundaries_tabulardata.xlsx", sheet_name='ADM1')

# %%
df_check
# Out:
#                      ADM1_EN          ADM1_TH ADM1_PCODE  ADM1_REF  \
# 0                    Bangkok    กรุงเทพมหานคร       TH10       NaN
# 1               Samut Prakan      สมุทรปราการ       TH11       NaN
# 2                 Nonthaburi          นนทบุรี       TH12       NaN
# 3               Pathum Thani         ปทุมธานี       TH13       NaN
# 4   Phra Nakhon Si Ayutthaya  พระนครศรีอยุธยา       TH14       NaN
# ..                       ...              ...        ...       ...
# 72                     Trang             ตรัง       TH92       NaN
# 73               Phatthalung           พัทลุง       TH93       NaN
# 74                   Pattani          ปัตตานี       TH94       NaN
# 75                      Yala             ยะลา       TH95       NaN
# 76                Narathiwat         นราธิวาส       TH96       NaN
#
#     ADM1ALT1_EN  ADM1ALT2_EN  ADM1ALT1_TH  ADM1ALT2_TH   ADM0_EN    ADM0_TH  \
# 0           NaN          NaN          NaN          NaN  Thailand  ประเทศไทย
# 1           NaN          NaN          NaN          NaN  Thailand  ประเทศไทย
# 2           NaN          NaN          NaN          NaN  Thailand  ประเทศไทย
# 3           NaN          NaN          NaN          NaN  Thailand  ประเทศไทย
# 4           NaN          NaN          NaN          NaN  Thailand  ประเทศไทย
# ..          ...          ...          ...          ...       ...        ...
# 72          NaN          NaN          NaN          NaN  Thailand  ประเทศไทย
# 73          NaN          NaN          NaN          NaN  Thailand  ประเทศไทย
# 74          NaN          NaN          NaN          NaN  Thailand  ประเทศไทย
# 75          NaN          NaN          NaN          NaN  Thailand  ประเทศไทย
# 76          NaN          NaN          NaN          NaN  Thailand  ประเทศไทย
#
#    ADM0_PCODE       DATE    VALIDON  VALIDTO    AREA_SQKM
# 0          TH 2019-02-18 2022-01-22      NaN  1571.371336
# 1          TH 2019-02-18 2022-01-22      NaN   949.001113
# 2          TH 2019-02-18 2022-01-22      NaN   636.542920
# 3          TH 2019-02-18 2022-01-22      NaN  1517.386645
# 4          TH 2019-02-18 2022-01-22      NaN  2553.360962
# ..        ...        ...        ...      ...          ...
# 72         TH 2019-02-18 2022-01-22      NaN  4709.743170
# 73         TH 2019-02-18 2022-01-22      NaN  3860.383277
# 74         TH 2019-02-18 2022-01-22      NaN  1966.320520
# 75         TH 2019-02-18 2022-01-22      NaN  4472.740198
# 76         TH 2019-02-18 2022-01-22      NaN  4487.557450
#
# [77 rows x 15 columns]

# %%
df_check = df_check[['ADM1_EN', 'ADM1_TH', 'AREA_SQKM']]
df_check
# Out:
#                      ADM1_EN          ADM1_TH    AREA_SQKM
# 0                    Bangkok    กรุงเทพมหานคร  1571.371336
# 1               Samut Prakan      สมุทรปราการ   949.001113
# 2                 Nonthaburi          นนทบุรี   636.542920
# 3               Pathum Thani         ปทุมธานี  1517.386645
# 4   Phra Nakhon Si Ayutthaya  พระนครศรีอยุธยา  2553.360962
# ..                       ...              ...          ...
# 72                     Trang             ตรัง  4709.743170
# 73               Phatthalung           พัทลุง  3860.383277
# 74                   Pattani          ปัตตานี  1966.320520
# 75                      Yala             ยะลา  4472.740198
# 76                Narathiwat         นราธิวาส  4487.557450
#
# [77 rows x 3 columns]

# %%
from math import pi

# %%
area = 0
i = 0
target = 100 * 1.2
while not (area > target):
    area = pi * (i**2)
    i = i+0.5

print(area)
# Out:
# 132.73228961416876

# %%
df_check.rename(columns={"ADM1_EN": "English_name"}, inplace=True)
df_check.rename(columns={"ADM1_TH": "Thai_name"}, inplace = True)
df_check.rename(columns={"AREA_SQKM": "AREA"}, inplace = True)
# Out:
# /var/folders/yz/zvlp09kd3l12735_165qzk0c0000gn/T/ipykernel_79359/2392656376.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_check.rename(columns={"ADM1_EN": "English_name"}, inplace=True)
# /var/folders/yz/zvlp09kd3l12735_165qzk0c0000gn/T/ipykernel_79359/2392656376.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_check.rename(columns={"ADM1_TH": "Thai_name"}, inplace = True)
# /var/folders/yz/zvlp09kd3l12735_165qzk0c0000gn/T/ipykernel_79359/2392656376.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_check.rename(columns={"AREA_SQKM": "AREA"}, inplace = True)

# %%
df_check
# Out:
#                 English_name        Thai_name         AREA
# 0                    Bangkok    กรุงเทพมหานคร  1571.371336
# 1               Samut Prakan      สมุทรปราการ   949.001113
# 2                 Nonthaburi          นนทบุรี   636.542920
# 3               Pathum Thani         ปทุมธานี  1517.386645
# 4   Phra Nakhon Si Ayutthaya  พระนครศรีอยุธยา  2553.360962
# ..                       ...              ...          ...
# 72                     Trang             ตรัง  4709.743170
# 73               Phatthalung           พัทลุง  3860.383277
# 74                   Pattani          ปัตตานี  1966.320520
# 75                      Yala             ยะลา  4472.740198
# 76                Narathiwat         นราธิวาส  4487.557450
#
# [77 rows x 3 columns]

# %%
df_check[["English_name", "Thai_name"]].drop_duplicates()
# Out:
#                 English_name        Thai_name
# 0                    Bangkok    กรุงเทพมหานคร
# 1               Samut Prakan      สมุทรปราการ
# 2                 Nonthaburi          นนทบุรี
# 3               Pathum Thani         ปทุมธานี
# 4   Phra Nakhon Si Ayutthaya  พระนครศรีอยุธยา
# ..                       ...              ...
# 72                     Trang             ตรัง
# 73               Phatthalung           พัทลุง
# 74                   Pattani          ปัตตานี
# 75                      Yala             ยะลา
# 76                Narathiwat         นราธิวาส
#
# [77 rows x 2 columns]

# %%
df_pmmap = pd.read_csv("../../data/a1/PM_map.csv")
df_pmmap
# Out:
#    รหัสสถานี                                         ชื่อสถานี  \
# 0        02T                      แขวงหิรัญรูจี เขตธนบุรี กทม.
# 1        05T                           แขวงบางนา เขตบางนา กทม.
# 2        10T                      แขวงคลองจั่น เขตบางกะปิ กทม.
# 3        11T                         แขวงดินแดง เขตดินแดง กทม.
# 4        12T                     แขวงช่องนนทรี เขตยานนาวา กทม.
# 5        59T                           แขวงพญาไท เขตพญาไท กทม.
# 6        61T                    แขวงพลับพลา เขตวังทองหลาง กทม.
# 7        03T   ริมถนนกาญจนาภิเษก แขวงแสมดำ เขตบางขุนเทียน กทม.
# 8        50T       ริมถนนพระรามสี่ แขวงปทุมวัน เขตปทุมวัน กทม.
# 9        52T  ริมถนนอินทรพิทักษ์ แขวงบางยี่เรือ เขตธนบุรี กทม.
# 72                       สำนักงานสาธารณสุขอำเภอแม่สาย         จ.เชียงราย
# 73  สำนักงานทรัพยากรธรรมชาติและสิ่งแวดล้อมจังหวัด ...       จ.แม่ฮ่องสอน
# 74                            สำนักงานเทศบาลเมืองน่าน             จ.น่าน
# 75                      โรงพยาบาลเฉลิมพระเกียรติ น่าน             จ.น่าน
# 76                            สถานีอุตุนิยมวิทยาลำพูน            จ.ลำพูน
# 77                            สถานีอุตุนิยมวิทยาแพร่                แพร่
# 78                               สนามกีฬาจังหวัดพะเยา            จ.พะเยา
# 79                    ศูนย์การศึกษานอกระบบอำเภอแม่สอด              จ.ตาก
# 80     สวนชมน่าน บริเวณหน้าวิทยาลัยอาชีวศึกษาพิษณุโลก         จ.พิษณุโลก
# 81  บริเวณภายในพื้นที่สวนมหามงคลเฉลิมพระเกียรติพระ...        จ.อุตรดิตถ์
# 82                ลานอนุรักษ์วัฒนธรรมไทยสิริจิตอุทยาน        จ.กำแพงเพชร
# 83                              สนามกีฬาจังหวัดพิจิตร           จ.พิจิตร
# 84                             สวนสาธารณะ ชุมชนเลอไทย          จ.สุโขทัย
# 85                                  สวนสาธารณะเพชบุระ        จ.เพชรบูรณ์
# 86  สวนเฉลิมพระเกียรติพระบาทสมเด็จพระเจ้าอยู่หัว เ...        จ.อุทัยธานี
# 87          สำนักงานสิ่งแวดล้อมภาคที่ ๑๔ สุราษฎร์ธานี     จ.สุราษฏร์ธานี
# 88                ศูนย์บริการสาธารณสุขเทศบาลนครภูเก็ต           จ.ภูเก็ต
# 89                                   เทศบาลนครหาดใหญ่            จ.สงขลา
# 90                            ศาลากลางจังหวัดนราธิวาส         จ.นราธิวาส
# 91                สวนสาธารณะสนามโรงพิธีช้างเผือก ยะลา             จ.ยะลา
# 92                  ศูนย์พัฒนาเด็กเล็กเทศบาลเมืองเบตง             จ.ยะลา
# 93                                ศาลากลางจังหวัดสตูล             จ.สตูล
# 94                        ศูนย์ฟื้นฟูสุขภาพผู้สูงอายุ    จ.นครศรีธรรมราช
# 95                             วิทยาลัยสารพัดช่างตรัง             จ.ตรัง
#
#                 english_name  adm1__id
# 0         Bangkok Metropolis       3.0
# 1         Bangkok Metropolis       3.0
# 2         Bangkok Metropolis       3.0
# 3         Bangkok Metropolis       3.0
# 4         Bangkok Metropolis       3.0
# 5         Bangkok Metropolis       3.0
# 6         Bangkok Metropolis       3.0
# 7         Bangkok Metropolis       3.0
# 8         Bangkok Metropolis       3.0
# 9         Bangkok Metropolis       3.0
# 10        Bangkok Metropolis       3.0
# 11        Bangkok Metropolis       3.0
# 12              Samut Prakan      57.0
# 13              Samut Prakan      57.0
# 14              Samut Prakan      57.0
# 15              Samut Prakan      57.0
# 16              Samut Prakan      57.0
# 17                Nonthaburi      36.0
# 18                Nonthaburi      36.0
# 19              Samut Sakhon      58.0
# 20              Samut Sakhon      58.0
# 21              Pathum Thani      37.0
# 22             Nakhon Pathom      27.0
# 23  Phra Nakhon Si Ayutthaya      46.0
# 24                       NaN       NaN
# 25                       NaN       NaN
# 26                Ratchaburi      52.0
# 27              Kanchanaburi      16.0
# 28           Samut Songkhram      59.0
# 29               Suphan Buri      66.0
# 30                  Lop Buri      22.0
# 31       Prachuap Khiri Khan      50.0
# 32                 Sing Buri      63.0
# 33                 Khon Kaen      17.0
# 34         Nakhon Ratchasima      29.0
# 35                      Loei      21.0
# 36                 Nong Khai      35.0
# 37          Ubon Ratchathani      72.0
# 38             Nakhon Phanom      28.0
# 39              Sakon Nakhon      56.0
# 40                Udon Thani      73.0
# 41                  Buri Ram       5.0
# 42                  Mukdahan      25.0
# 43                 Bueng Kan       4.0
# 44                   Kalasin      14.0
# 45                Chaiyaphum       8.0
# 46                  Yasothon      77.0
# 47             Amnat Charoen       1.0
# 48                     Surin      68.0
# 49                 Si Sa Ket      62.0
# 50                    Rayong      53.0
# 51                    Rayong      53.0
# 52                    Rayong      53.0
# 53                    Rayong      53.0
# 54                    Rayong      53.0
# 55                 Chon Buri      12.0
# 56                 Chon Buri      12.0
# 57                 Chon Buri      12.0
# 58              Chachoengsao       6.0
# 59                       NaN       NaN
# 60              Prachin Buri      49.0
# 61                      Trat      71.0
# 62               Chanthaburi       9.0
# 63              Nakhon Nayok      26.0
# 64                Chiang Mai      10.0
# 65                Chiang Mai      10.0
# 66                   Lampang      19.0
# 67                   Lampang      19.0
# 68                   Lampang      19.0
# 69                   Lampang      19.0
# 70              Nakhon Sawan      30.0
# 71                Chiang Rai      11.0
# 72                Chiang Rai      11.0
# 73              Mae Hong Son      23.0
# 74                       Nan      32.0
# 75                       Nan      32.0
# 76                   Lamphun      20.0
# 77                     Phrae      47.0
# 78                    Phayao      41.0
# 79                       Tak      69.0
# 80               Phitsanulok      45.0
# 81                 Uttaradit      75.0
# 82            Kamphaeng Phet      15.0
# 83                   Phichit      44.0
# 84                 Sukhothai      65.0
# 85                Phetchabun      42.0
# 86               Uthai Thani      74.0
# 87               Surat Thani      67.0
# 88                    Phuket      48.0
# 89                  Songkhla      64.0
# 90                Narathiwat      33.0
# 91                      Yala      76.0
# 92                      Yala      76.0
# 93                     Satun      61.0
# 94       Nakhon Si Thammarat      31.0
# 95                     Trang      70.0

# %%
df_check.loc[df_check["English_name"] == "Bangkok", "English_name"] = "Bangkok Metropolis"
df_check
# Out:
#                 English_name        Thai_name          AREA
# 0         Bangkok Metropolis    กรุงเทพมหานคร   1571.371336
# 1               Samut Prakan      สมุทรปราการ    949.001113
# 2                 Nonthaburi          นนทบุรี    636.542920
# 3               Pathum Thani         ปทุมธานี   1517.386645
# 4   Phra Nakhon Si Ayutthaya  พระนครศรีอยุธยา   2553.360962
# 5                  Ang Thong          อ่างทอง    944.216921
# 6                   Lop Buri           ลพบุรี   6491.816312
# 7                  Sing Buri        สิงห์บุรี    818.192131
# 8                   Chai Nat           ชัยนาท   2486.567838
# 9                   Saraburi          สระบุรี   3481.759648
# 10                 Chon Buri           ชลบุรี   4504.763605
# 11                    Rayong            ระยอง   3682.137154
# 12               Chanthaburi         จันทบุรี   6403.634178
# 13                      Trat             ตราด   2869.424644
# 14              Chachoengsao       ฉะเชิงเทรา   5165.910411
# 15              Prachin Buri       ปราจีนบุรี   5046.991953
# 76                Narathiwat         นราธิวาส   4487.557450

# %%
df_adminid = pd.read_csv("../../data/Wild_Fire/Cumulative Fire Alerts in Thailand/adm1_metadata.csv")
df_adminid
# Out:
#                         name  adm1__id
# 0              Amnat Charoen         1
# 1                  Ang Thong         2
# 2         Bangkok Metropolis         3
# 3                  Bueng Kan         4
# 4                   Buri Ram         5
# 5               Chachoengsao         6
# 6                   Chai Nat         7
# 7                 Chaiyaphum         8
# 8                Chanthaburi         9
# 9                 Chiang Mai        10
# 10                Chiang Rai        11
# 11                 Chon Buri        12
# 12                  Chumphon        13
# 13                   Kalasin        14
# 14            Kamphaeng Phet        15
# 15              Kanchanaburi        16
# 16                 Khon Kaen        17
# 17                     Krabi        18
# 18                   Lampang        19
# 19                   Lamphun        20
# 20                      Loei        21
# 21                  Lop Buri        22
# 22              Mae Hong Son        23
# 23             Maha Sarakham        24
# 24                  Mukdahan        25
# 25              Nakhon Nayok        26
# 26             Nakhon Pathom        27
# 27             Nakhon Phanom        28
# 28         Nakhon Ratchasima        29
# 29              Nakhon Sawan        30
# 30       Nakhon Si Thammarat        31
# 31                       Nan        32
# 32                Narathiwat        33
# 33          Nong Bua Lam Phu        34
# 34                 Nong Khai        35
# 35                Nonthaburi        36
# 36              Pathum Thani        37
# 37                   Pattani        38
# 38                  Phangnga        39
# 39               Phatthalung        40
# 40                    Phayao        41
# 41                Phetchabun        42
# 42               Phetchaburi        43
# 43                   Phichit        44
# 44               Phitsanulok        45
# 45  Phra Nakhon Si Ayutthaya        46
# 46                     Phrae        47
# 47                    Phuket        48
# 48              Prachin Buri        49
# 49       Prachuap Khiri Khan        50
# 50                    Ranong        51
# 51                Ratchaburi        52
# 52                    Rayong        53
# 53                    Roi Et        54
# 54                   Sa Kaeo        55
# 55              Sakon Nakhon        56
# 56              Samut Prakan        57
# 57              Samut Sakhon        58
# 58           Samut Songkhram        59
# 59                  Saraburi        60
# 60                     Satun        61
# 61                 Si Sa Ket        62
# 62                 Sing Buri        63
# 63                  Songkhla        64
# 64                 Sukhothai        65
# 65               Suphan Buri        66
# 66               Surat Thani        67
# 67                     Surin        68
# 68                       Tak        69
# 69                     Trang        70
# 70                      Trat        71
# 71          Ubon Ratchathani        72
# 72                Udon Thani        73
# 73               Uthai Thani        74
# 74                 Uttaradit        75
# 75                      Yala        76
# 76                  Yasothon        77

# %%
# Map 'adm1__id' from df_adminid to df_check based on 'English_name'
df_check['adm1_id'] = df_check['English_name'].map(df_adminid.set_index('name')['adm1__id'])

# Verify the mapping
df_check['adm1_id'] == df_adminid.set_index('name').loc[df_check['English_name'], 'adm1__id'].values

df_check[['English_name', 'adm1_id']]
# Out:
# /var/folders/yz/zvlp09kd3l12735_165qzk0c0000gn/T/ipykernel_79359/374992257.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_check['adm1_id'] = df_check['English_name'].map(df_adminid.set_index('name')['adm1__id'])
#                 English_name  adm1_id
# 0         Bangkok Metropolis        3
# 1               Samut Prakan       57
# 2                 Nonthaburi       36
# 3               Pathum Thani       37
# 4   Phra Nakhon Si Ayutthaya       46
# 5                  Ang Thong        2
# 6                   Lop Buri       22
# 7                  Sing Buri       63
# 8                   Chai Nat        7
# 9                   Saraburi       60
# 10                 Chon Buri       12
# 11                    Rayong       53
# 12               Chanthaburi        9
# 13                      Trat       71
# 14              Chachoengsao        6
# 15              Prachin Buri       49
# 16              Nakhon Nayok       26
# 17                   Sa Kaeo       55
# 18         Nakhon Ratchasima       29
# 19                  Buri Ram        5
# 20                     Surin       68
# 21                 Si Sa Ket       62
# 22          Ubon Ratchathani       72
# 23                  Yasothon       77
# 24                Chaiyaphum        8
# 25             Amnat Charoen        1
# 26                 Bueng Kan        4
# 27          Nong Bua Lam Phu       34
# 28                 Khon Kaen       17
# 29                Udon Thani       73
# 30                      Loei       21
# 31                 Nong Khai       35
# 32             Maha Sarakham       24
# 33                    Roi Et       54
# 34                   Kalasin       14
# 35              Sakon Nakhon       56
# 36             Nakhon Phanom       28
# 37                  Mukdahan       25
# 38                Chiang Mai       10
# 39                   Lamphun       20
# 40                   Lampang       19
# 41                 Uttaradit       75
# 42                     Phrae       47
# 43                       Nan       32
# 44                    Phayao       41
# 45                Chiang Rai       11
# 46              Mae Hong Son       23
# 47              Nakhon Sawan       30
# 48               Uthai Thani       74
# 49            Kamphaeng Phet       15
# 50                       Tak       69
# 51                 Sukhothai       65
# 52               Phitsanulok       45
# 53                   Phichit       44
# 54                Phetchabun       42
# 55                Ratchaburi       52
# 56              Kanchanaburi       16
# 57               Suphan Buri       66
# 58             Nakhon Pathom       27
# 59              Samut Sakhon       58
# 60           Samut Songkhram       59
# 61               Phetchaburi       43
# 62       Prachuap Khiri Khan       50
# 63       Nakhon Si Thammarat       31
# 64                     Krabi       18
# 65                  Phangnga       39
# 66                    Phuket       48
# 67               Surat Thani       67
# 68                    Ranong       51
# 69                  Chumphon       13
# 70                  Songkhla       64
# 71                     Satun       61
# 72                     Trang       70
# 73               Phatthalung       40
# 74                   Pattani       38
# 75                      Yala       76
# 76                Narathiwat       33

# %%
pd.set_option('display.max_rows', None)

df_check.sort_values('adm1_id', inplace=True)
print(df_check)

#reset display options as default
pd.reset_option('display.max_rows')
# Out:
#                 English_name        Thai_name          AREA  adm1_id
# 25             Amnat Charoen       อำนาจเจริญ   3262.571368        1
# 5                  Ang Thong          อ่างทอง    944.216921        2
# 0         Bangkok Metropolis    กรุงเทพมหานคร   1571.371336        3
# 26                 Bueng Kan           บึงกาฬ   3991.221379        4
# 19                  Buri Ram        บุรีรัมย์  10058.251514        5
# 14              Chachoengsao       ฉะเชิงเทรา   5165.910411        6
# 8                   Chai Nat           ชัยนาท   2486.567838        7
# 24                Chaiyaphum          ชัยภูมิ  12615.756015        8
# 12               Chanthaburi         จันทบุรี   6403.634178        9
# 38                Chiang Mai        เชียงใหม่  22176.037103       10
# 45                Chiang Rai         เชียงราย  11584.266449       11
# 10                 Chon Buri           ชลบุรี   4504.763605       12
# 69                  Chumphon            ชุมพร   6021.565231       13
# 34                   Kalasin        กาฬสินธุ์   6888.070231       14
# 49            Kamphaeng Phet        กำแพงเพชร   8557.992477       15
# 56              Kanchanaburi        กาญจนบุรี  19450.911388       16
# 28                 Khon Kaen          ขอนแก่น  10612.202446       17
# 64                     Krabi           กระบี่   4988.355388       18
# 40                   Lampang            ลำปาง  12496.449201       19
# 39                   Lamphun            ลำพูน   4482.900029       20
# 30                      Loei              เลย  10503.181724       21
# 6                   Lop Buri           ลพบุรี   6491.816312       22
# 46              Mae Hong Son       แม่ฮ่องสอน  12771.977613       23
# 32             Maha Sarakham        มหาสารคาม   5607.557625       24
# 37                  Mukdahan         มุกดาหาร   4111.206259       25
# 16              Nakhon Nayok          นครนายก   2136.473514       26
# 58             Nakhon Pathom           นครปฐม   2139.199174       27
# 36             Nakhon Phanom           นครพนม   5585.723559       28
# 18         Nakhon Ratchasima       นครราชสีมา  20709.129379       29
# 47              Nakhon Sawan        นครสวรรค์   9513.303173       30
# 63       Nakhon Si Thammarat    นครศรีธรรมราช   9901.712714       31
# 43                       Nan             น่าน  12190.705498       32
# 76                Narathiwat         นราธิวาส   4487.557450       33
# 27          Nong Bua Lam Phu      หนองบัวลำภู   4064.126376       34
# 31                 Nong Khai          หนองคาย   3271.149204       35
# 2                 Nonthaburi          นนทบุรี    636.542920       36
# 3               Pathum Thani         ปทุมธานี   1517.386645       37
# 74                   Pattani          ปัตตานี   1966.320520       38
# 65                  Phangnga            พังงา   4095.731358       39
# 73               Phatthalung           พัทลุง   3860.383277       40
# 44                    Phayao            พะเยา   6195.606609       41
# 54                Phetchabun        เพชรบูรณ์  12388.984479       42
# 61               Phetchaburi         เพชรบุรี   6183.000804       43
# 53                   Phichit           พิจิตร   4336.405165       44
# 52               Phitsanulok         พิษณุโลก  10523.255004       45
# 4   Phra Nakhon Si Ayutthaya  พระนครศรีอยุธยา   2553.360962       46
# 42                     Phrae             แพร่   6488.019856       47
# 66                    Phuket           ภูเก็ต    548.025456       48
# 15              Prachin Buri       ปราจีนบุรี   5046.991953       49
# 62       Prachuap Khiri Khan  ประจวบคีรีขันธ์   6448.389536       50
# 68                    Ranong            ระนอง   3293.485117       51
# 55                Ratchaburi          ราชบุรี   5202.252245       52
# 11                    Rayong            ระยอง   3682.137154       53
# 33                    Roi Et         ร้อยเอ็ด   7819.053663       54
# 17                   Sa Kaeo          สระแก้ว   6788.908965       55
# 35              Sakon Nakhon           สกลนคร   9526.968864       56
# 1               Samut Prakan      สมุทรปราการ    949.001113       57
# 59              Samut Sakhon        สมุทรสาคร    856.875513       58
# 60           Samut Songkhram      สมุทรสงคราม    414.390807       59
# 9                   Saraburi          สระบุรี   3481.759648       60
# 71                     Satun             สตูล   2881.574144       61
# 21                 Si Sa Ket         ศรีสะเกษ   8884.980063       62
# 7                  Sing Buri        สิงห์บุรี    818.192131       63
# 70                  Songkhla            สงขลา   7741.350404       64
# 51                 Sukhothai          สุโขทัย   6680.174061       65
# 57               Suphan Buri       สุพรรณบุรี   5433.457336       66
# 67               Surat Thani     สุราษฎร์ธานี  13085.453392       67
# 20                     Surin         สุรินทร์   8815.660458       68
# 50                       Tak              ตาก  17279.668009       69
# 72                     Trang             ตรัง   4709.743170       70
# 13                      Trat             ตราด   2869.424644       71
# 22          Ubon Ratchathani      อุบลราชธานี  15482.814061       72
# 29                Udon Thani         อุดรธานี  11054.261328       73
# 48               Uthai Thani        อุทัยธานี   6638.454694       74
# 41                 Uttaradit        อุตรดิตถ์   7919.274810       75
# 75                      Yala             ยะลา   4472.740198       76
# 23                  Yasothon            ยโสธร   4097.293958       77
# /var/folders/yz/zvlp09kd3l12735_165qzk0c0000gn/T/ipykernel_79359/598184385.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_check.sort_values('adm1_id', inplace=True)

# %%
data = pd.read_json("data.json")

# If you need to skip the first row, you can drop it after loading the data
data = data.iloc[0:]

# %%
data
# Out:
#                  0         1          2
# 0         Location  Latitude  Longitude
# 1    Amnat Charoen   15°51'N   104°38'E
# 2        Ang Thong   14°35'N   100°31'E
# 3    Aranyaprathet   13°41'N   102°30'E
# 4     Ban Bang Hin   09°32'N    98°35'E
# ..             ...       ...        ...
# 131        Lom Sak   16°47'N   101°15'E
# 132       Lop Buri   14°48'N   100°37'E
# 133   Luang, Thale   07°30'N   100°15'E
# 134       Mae Chan   20°09'N    99°52'E
# 135   Mae Hong Son   19°16'N    97°56'E
#
# [136 rows x 3 columns]

# %%
#index 0 is column names
data.columns = data.iloc[0]
data = data[1:]
data.reset_index(drop=True, inplace=True)

data
# Out:
# 0            Location Latitude Longitude
# 0       Amnat Charoen  15°51'N  104°38'E
# 1           Ang Thong  14°35'N  100°31'E
# 2       Aranyaprathet  13°41'N  102°30'E
# 3        Ban Bang Hin  09°32'N   98°35'E
# 4    Ban Chiang Klang  19°25'N  100°55'E
# ..                ...      ...       ...
# 130           Lom Sak  16°47'N  101°15'E
# 131          Lop Buri  14°48'N  100°37'E
# 132      Luang, Thale  07°30'N  100°15'E
# 133          Mae Chan  20°09'N   99°52'E
# 134      Mae Hong Son  19°16'N   97°56'E
#
# [135 rows x 3 columns]

# %%
# Check if the 'Location' column in 'data' matches any province in 'df_check["English_name"]'
data['is_province'] = data['Location'].isin(df_check['English_name'])

# Display the rows where 'is_province' is True
data[data['is_province']]
# Out:
# /var/folders/yz/zvlp09kd3l12735_165qzk0c0000gn/T/ipykernel_79359/3280862945.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['is_province'] = data['Location'].isin(df_check['English_name'])
# 0          Location Latitude Longitude  is_province
# 0     Amnat Charoen  15°51'N  104°38'E         True
# 1         Ang Thong  14°35'N  100°31'E         True
# 52     Chachoengsao  13°42'N  101°05'E         True
# 60      Chanthaburi  12°38'N  102°12'E         True
# 70       Chiang Mai  18°47'N   98°59'E         True
# 71       Chiang Rai  19°52'N   99°50'E         True
# 76        Chon Buri  13°21'N  101°01'E         True
# 80         Chumphon  10°35'N   99°14'E         True
# 95          Kalasin  16°26'N  103°30'E         True
# 96   Kamphaeng Phet  16°28'N   99°30'E         True
# 98     Kanchanaburi  14°02'N   99°31'E         True
# 105       Khon Kaen  16°30'N  102°47'E         True
# 114           Krabi  08°04'N   98°55'E         True
# 122         Lampang  18°16'N   99°32'E         True
# 128            Loei  17°29'N  101°35'E         True
# 131        Lop Buri  14°48'N  100°37'E         True
# 134    Mae Hong Son  19°16'N   97°56'E         True

# %%
df_provinces = pd.read_csv("../../data/boundaries/provinces.csv")
df_provinces
# Out:
#     province_id  province_name  province_lat  province_lon  province_zoom
# 0             1  กรุงเทพมหานคร     13.727896    100.524123             13
# 1             2         กระบี่      8.086300     98.906283             13
# 2             3      กาญจนบุรี     14.022780     99.532811             13
# 3             4      กาฬสินธุ์     16.431408    103.505876             13
# 4             5      กำแพงเพชร     16.482780     99.522662             13
# ..          ...            ...           ...           ...            ...
# 72           73       อุดรธานี     17.413841    102.787233             13
# 73           74      อุตรดิตถ์     17.620089    100.099294             13
# 74           75      อุทัยธานี     15.383500    100.024553             13
# 75           76    อุบลราชธานี     15.228686    104.856422             13
# 76           77         บึงกาฬ     18.360910    103.646446             13
#
# [77 rows x 5 columns]

# %%
df_provinces['is_province'] = df_provinces['province_name'].isin(df_check['Thai_name'])
df_provinces[df_provinces['is_province']]
# Out:
#     province_id  province_name  province_lat  province_lon  province_zoom  \
# 0             1  กรุงเทพมหานคร     13.727896    100.524123             13
# 1             2         กระบี่      8.086300     98.906283             13
# 2             3      กาญจนบุรี     14.022780     99.532811             13
# 3             4      กาฬสินธุ์     16.431408    103.505876             13
# 4             5      กำแพงเพชร     16.482780     99.522662             13
# ..          ...            ...           ...           ...            ...
# 72           73       อุดรธานี     17.413841    102.787233             13
# 73           74      อุตรดิตถ์     17.620089    100.099294             13
# 74           75      อุทัยธานี     15.383500    100.024553             13
# 75           76    อุบลราชธานี     15.228686    104.856422             13
# 76           77         บึงกาฬ     18.360910    103.646446             13
#
#     is_province
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# ..          ...
# 72         True
# 73         True
# 74         True
# 75         True
# 76         True
#
# [77 rows x 6 columns]

# %%
# กทม
# เชียงใหม่
# กาญ
# ขอนแก่น
# ภูเก็ต
# ชลบุรี

df_use = df_provinces[df_provinces['province_name'].isin(["กรุงเทพมหานคร", "เชียงใหม่", "กาญจนบุรี", "ขอนแก่น", "ภูเก็ต", "ชลบุรี"])]

# %%
df_use
# Out:
#     province_id  province_name  province_lat  province_lon  province_zoom  \
# 0             1  กรุงเทพมหานคร     13.727896    100.524123             13
# 2             3      กาญจนบุรี     14.022780     99.532811             13
# 5             6        ขอนแก่น     16.441935    102.835992             13
# 8             9         ชลบุรี     13.361143    100.984672             13
# 13           14      เชียงใหม่     18.787748     98.993131             13
# 40           41         ภูเก็ต      7.981050     98.363882             13
#
#     is_province
# 0          True
# 2          True
# 5          True
# 8          True
# 13         True
# 40         True

# %%
df_use.drop(columns=['province_id', 'province_zoom', 'is_province'], inplace=True)
# Out:
# /var/folders/yz/zvlp09kd3l12735_165qzk0c0000gn/T/ipykernel_79359/4223902965.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_use.drop(columns=['province_id', 'province_zoom', 'is_province'], inplace=True)

# %%
df_use.reset_index(drop=True, inplace=True)

# %%
df_use
# Out:
#    province_name  province_lat  province_lon
# 0  กรุงเทพมหานคร     13.727896    100.524123
# 1      กาญจนบุรี     14.022780     99.532811
# 2        ขอนแก่น     16.441935    102.835992
# 3         ชลบุรี     13.361143    100.984672
# 4      เชียงใหม่     18.787748     98.993131
# 5         ภูเก็ต      7.981050     98.363882

# %%
df_use = df_use.merge(df_check, left_on='province_name', right_on='Thai_name', how='left')

# %%
df_use
# Out:
#    province_name  province_lat  province_lon        English_name  \
# 0  กรุงเทพมหานคร     13.727896    100.524123  Bangkok Metropolis
# 1      กาญจนบุรี     14.022780     99.532811        Kanchanaburi
# 2        ขอนแก่น     16.441935    102.835992           Khon Kaen
# 3         ชลบุรี     13.361143    100.984672           Chon Buri
# 4      เชียงใหม่     18.787748     98.993131          Chiang Mai
# 5         ภูเก็ต      7.981050     98.363882              Phuket
#
#        Thai_name          AREA  adm1_id
# 0  กรุงเทพมหานคร   1571.371336        3
# 1      กาญจนบุรี  19450.911388       16
# 2        ขอนแก่น  10612.202446       17
# 3         ชลบุรี   4504.763605       12
# 4      เชียงใหม่  22176.037103       10
# 5         ภูเก็ต    548.025456       48

# %%
df_use.drop(columns=['adm1_id', 'Thai_name'], inplace=True)

# %%
df_use
# Out:
#    province_name  province_lat  province_lon        English_name          AREA
# 0  กรุงเทพมหานคร     13.727896    100.524123  Bangkok Metropolis   1571.371336
# 1      กาญจนบุรี     14.022780     99.532811        Kanchanaburi  19450.911388
# 2        ขอนแก่น     16.441935    102.835992           Khon Kaen  10612.202446
# 3         ชลบุรี     13.361143    100.984672           Chon Buri   4504.763605
# 4      เชียงใหม่     18.787748     98.993131          Chiang Mai  22176.037103
# 5         ภูเก็ต      7.981050     98.363882              Phuket    548.025456

# %%
df_use.to_csv("../../data/a1/indicator.csv", index=False)

# %%
df_pmmap.drop(columns=['จังหวัด', 'adm1__id'], inplace=True)

# %%
df_pmmap
# Out:
#    รหัสสถานี                       ชื่อสถานี  \
# 0        02T    แขวงหิรัญรูจี เขตธนบุรี กทม.
# 1        05T         แขวงบางนา เขตบางนา กทม.
# 2        10T    แขวงคลองจั่น เขตบางกะปิ กทม.
# 3        11T       แขวงดินแดง เขตดินแดง กทม.
# 4        12T   แขวงช่องนนทรี เขตยานนาวา กทม.
# ..       ...                             ...
# 91       63T          ต.สะเตง อ.เมือง จ.ยะลา
# 92       78T            ต.เบตง อ.เบตง จ.ยะลา
# 93       80T         ต.พิมาน อ.เมือง. จ.สตูล
# 94       89T  ต.คลัง อ.เมือง จ.นครศรีธรรมราช
# 95       93T   ต.นาตาล่วง อ.เมืองตรัง จ.ตรัง
#
#                รายละเอียดจุดติดตั้งสถานี         english_name
# 0   มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา   Bangkok Metropolis
# 1                       กรมอุตุนิยมวิทยา   Bangkok Metropolis
# 2                      เคหะชุมชนคลองจั่น   Bangkok Metropolis
# 3              สนามกีฬาเคหะชุมชนห้วยขวาง   Bangkok Metropolis
# 4                     โรงเรียนนนทรีวิทยา   Bangkok Metropolis
# ..                                   ...                  ...
# 91   สวนสาธารณะสนามโรงพิธีช้างเผือก ยะลา                 Yala
# 92     ศูนย์พัฒนาเด็กเล็กเทศบาลเมืองเบตง                 Yala
# 93                   ศาลากลางจังหวัดสตูล                Satun
# 94           ศูนย์ฟื้นฟูสุขภาพผู้สูงอายุ  Nakhon Si Thammarat
# 95                วิทยาลัยสารพัดช่างตรัง                Trang
#
# [96 rows x 4 columns]

# %%
df_pmmap.to_csv("../../data/a1/PM_map.csv", index=False)
